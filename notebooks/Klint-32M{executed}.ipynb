# %% [markdown]
# #  Klint-32M: Generative Financial Foundation Architecture
#
# > **Klint** is an open research foundation architecture for generative financial time-series modeling.
# > Author: Akhilesh Varma (`akhverm@gmail.com`)
# > Target Scale: **Klint-32M** (~30.6M parameters: 10 layers, 480 hidden dimension, 10 heads).
#
# This notebook provides the **complete, end-to-end production workflow**:
# 1. **Pre-training / Resuming** the 32M foundation model with zero-overhead In-VRAM tensor slicing.
# 2. **Generating** guaranteed structurally valid OHLCV synthetic trajectories ($H \ge \max(O, C), L \le \min(O, C)$).
# 3. **Rigorous Multi-Asset Testing Suite** testing across **300+ liquid assets across 6 asset classes** via `yfinance`.
# 4. **Automated Risk & Return Reporting**: Drawdown curves, Directional Hit Rate distributions, Sharpe rankings, and structured CSV logs.
#
# *Note: All models, data, CSVs, and plots are stored directly inside the local environment (`./checkpoints/`, `./benchmarks/`) with zero Google Drive dependency.*

# %% [markdown]
# ## 1. Hardware Detection & Accelerator Auto-Tuning
# Detects available GPU (T4, V100, A100, or L4) and configures optimal precision.

# %%
# !nvidia-smi

import torch
print(f"PyTorch Version: {torch.__version__}")
print(f"CUDA Available: {torch.cuda.is_available()}")

if torch.cuda.is_available():
    gpu_name = torch.cuda.get_device_name(0)
    total_vram = torch.cuda.get_device_properties(0).total_memory / (1024**3)
    bf16_ok = torch.cuda.is_bf16_supported()
    print(f"GPU Detected: {gpu_name} ({total_vram:.2f} GB VRAM)")
    print(f"bfloat16 Acceleration Supported: {bf16_ok}")
else:
    print("WARNING: No GPU detected! Please go to Runtime -> Change runtime type -> Select GPU (T4 or A100).")
# Out:
# Tue Sep 22 09:22:28 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   46C    P8             11W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
# PyTorch Version: 2.11.0+cu128
# CUDA Available: True
# GPU Detected: Tesla T4 (14.56 GB VRAM)
# bfloat16 Acceleration Supported: True

# %% [markdown]
# ## 2. Environment Setup & Architectural Invariant Checks
# Installs dependencies, ensures `klint` is in Python's path, and runs pytest to verify all invariant guarantees.

# %%
import sys, os
sys.path.insert(0, '/content/Klint-32M/src')
sys.path.insert(0, os.path.abspath('src'))

# If running in Colab from cloned repo:
# !git clone https://github.com/ak495867/Klint-32M.git
# %cd /content/Klint-32M

# !pip install -e ".[dev]"
# !pip install yfinance matplotlib pandas scipy
# !pytest tests/ -v
# !mkdir -p checkpoints data benchmarks/reports benchmarks/plots
# Out:
# Cloning into 'Klint-32M'...
# remote: Enumerating objects: 133, done.
# remote: Counting objects: 100% (133/133), done.
# remote: Compressing objects: 100% (99/99), done.
# remote: Total 133 (delta 39), reused 117 (delta 25), pack-reused 0 (from 0)
# Receiving objects: 100% (133/133), 39.22 MiB | 13.43 MiB/s, done.
# Resolving deltas: 100% (39/39), done.
# /content/Klint-32M
# Obtaining file:///content/Klint-32M
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: torch>=2.1.0 in /usr/local/lib/python3.13/dist-packages (from klint==0.1.0) (2.11.0+cu128)
# Requirement already satisfied: numpy>=1.24.0 in /usr/local/lib/python3.13/dist-packages (from klint==0.1.0) (2.1.3)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.13/dist-packages (from klint==0.1.0) (1.16.3)
# Requirement already satisfied: pyyaml>=6.0 in /usr/local/lib/python3.13/dist-packages (from klint==0.1.0) (6.0.3)
# Requirement already satisfied: pandas>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from klint==0.1.0) (2.2.3)
# Requirement already satisfied: pytest>=7.0.0 in /usr/local/lib/python3.13/dist-packages (from klint==0.1.0) (8.4.2)
# Collecting pytest-cov>=4.0.0 (from klint==0.1.0)
#   Downloading pytest_cov-7.1.0-py3-none-any.whl.metadata (32 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.13/dist-packages (from pandas>=2.0.0->klint==0.1.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.13/dist-packages (from pandas>=2.0.0->klint==0.1.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.13/dist-packages (from pandas>=2.0.0->klint==0.1.0) (2026.3)
# Requirement already satisfied: iniconfig>=1 in /usr/local/lib/python3.13/dist-packages (from pytest>=7.0.0->klint==0.1.0) (2.3.0)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.13/dist-packages (from pytest>=7.0.0->klint==0.1.0) (26.3)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.13/dist-packages (from pytest>=7.0.0->klint==0.1.0) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in /usr/local/lib/python3.13/dist-packages (from pytest>=7.0.0->klint==0.1.0) (2.21.0)
# Collecting coverage>=7.10.6 (from coverage[toml]>=7.10.6->pytest-cov>=4.0.0->klint==0.1.0)
#   Downloading coverage-7.16.1-cp313-cp313-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (8.2 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.13/dist-packages (from torch>=2.1.0->klint==0.1.0) (3.32.5)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.13/dist-packages (from torch>=2.1.0->klint==0.1.0) (4.16.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.13/dist-packages (from torch>=2.1.0->klint==0.1.0) (80.10.2)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.13/dist-packages (from torch>=2.1.0->klint==0.1.0) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.13/dist-packages (from torch>=2.1.0->klint==0.1.0) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.13/dist-packages (from torch>=2.1.0->klint==0.1.0) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.13/dist-packages (from torch>=2.1.0->klint==0.1.0) (2025.12.0)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.1.0->klint==0.1.0) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.13/dist-packages (from torch>=2.1.0->klint==0.1.0) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.13/dist-packages (from torch>=2.1.0->klint==0.1.0) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.13/dist-packages (from torch>=2.1.0->klint==0.1.0) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.13/dist-packages (from torch>=2.1.0->klint==0.1.0) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.13/dist-packages (from torch>=2.1.0->klint==0.1.0) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.13/dist-packages (from torch>=2.1.0->klint==0.1.0) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.1.0->klint==0.1.0) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.1.0->klint==0.1.0) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.1.0->klint==0.1.0) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.1.0->klint==0.1.0) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.1.0->klint==0.1.0) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.1.0->klint==0.1.0) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.1.0->klint==0.1.0) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.1.0->klint==0.1.0) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.1.0->klint==0.1.0) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.1.0->klint==0.1.0) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.1.0->klint==0.1.0) (12.8.90)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.13/dist-packages (from cuda-bindings<13,>=12.9.4->torch>=2.1.0->klint==0.1.0) (1.8.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->klint==0.1.0) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from sympy>=1.13.3->torch>=2.1.0->klint==0.1.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.13/dist-packages (from jinja2->torch>=2.1.0->klint==0.1.0) (3.0.3)
# Downloading pytest_cov-7.1.0-py3-none-any.whl (22 kB)
# Downloading coverage-7.16.1-cp313-cp313-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (257 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 257.5/257.5 kB 19.4 MB/s eta 0:00:00
# Building wheels for collected packages: klint
#   Building editable for klint (pyproject.toml) ... done
#   Created wheel for klint: filename=klint-0.1.0-0.editable-py3-none-any.whl size=3760 sha256=4be60eca303083058dfec9ee2376d89eaee2225b405b5c9a9ac67c2176a6e841
#   Stored in directory: /tmp/pip-ephem-wheel-cache-xan8qnjt/wheels/22/eb/ab/06d640521cd6aa03c13a5e7ecb5e1af8cfc55db69c542294cc
# Successfully built klint
# Installing collected packages: coverage, pytest-cov, klint
# Successfully installed coverage-7.16.1 klint-0.1.0 pytest-cov-7.1.0
# Requirement already satisfied: yfinance in /usr/local/lib/python3.13/dist-packages (0.2.66)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.13/dist-packages (3.10.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.13/dist-packages (2.2.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.13/dist-packages (1.16.3)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.13/dist-packages (from yfinance) (2.1.3)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.13/dist-packages (from yfinance) (2.32.4)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.13/dist-packages (from yfinance) (0.0.13)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from yfinance) (4.11.7)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.13/dist-packages (from yfinance) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.13/dist-packages (from yfinance) (2.4.7)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.13/dist-packages (from yfinance) (4.4.0)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.13/dist-packages (from yfinance) (4.13.5)
# Requirement already satisfied: curl_cffi>=0.7 in /usr/local/lib/python3.13/dist-packages (from yfinance) (0.16.2)
# Requirement already satisfied: protobuf>=3.19.0 in /usr/local/lib/python3.13/dist-packages (from yfinance) (5.29.6)
# Requirement already satisfied: websockets>=13.0 in /usr/local/lib/python3.13/dist-packages (from yfinance) (15.0.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.13/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib) (4.64.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib) (1.5.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib) (26.3)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.13/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.13/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.13/dist-packages (from pandas) (2026.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.13/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.9.2)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.13/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (4.16.0)
# Requirement already satisfied: cffi>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from curl_cffi>=0.7->yfinance) (2.1.1)
# Requirement already satisfied: certifi>=2024.2.2 in /usr/local/lib/python3.13/dist-packages (from curl_cffi>=0.7->yfinance) (2026.7.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests>=2.31->yfinance) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.13/dist-packages (from requests>=2.31->yfinance) (3.19)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests>=2.31->yfinance) (2.5.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.13/dist-packages (from cffi>=2.0.0->curl_cffi>=0.7->yfinance) (3.0)
# ============================= test session starts ==============================
# platform linux -- Python 3.13.15, pytest-8.4.2, pluggy-1.6.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /content/Klint-32M
# configfile: pyproject.toml
# plugins: cov-7.1.0, anyio-4.14.2, typeguard-4.6.0, langsmith-0.12.1
# collected 11 items
#
# tests/test_factors.py::test_validator_detects_bad_candles PASSED         [  9%]
# tests/test_factors.py::test_factor_decomposition_shapes_and_values PASSED [ 18%]
# tests/test_factors.py::test_factor_decomposition_on_real_sol_data PASSED [ 27%]
# tests/test_geometry.py::test_geometric_decoder_invariants_random PASSED  [ 36%]
# tests/test_geometry.py::test_geometric_decoder_extreme_values PASSED     [ 45%]
# tests/test_tokenizer.py::test_vector_quantizer_forward_and_loss PASSED   [ 54%]
# tests/test_tokenizer.py::test_factor_tokenizer_roundtrip PASSED          [ 63%]
# tests/test_transformer.py::test_rmsnorm PASSED                           [ 72%]
# tests/test_transformer.py::test_causal_no_leakage PASSED                 [ 81%]
# tests/test_transformer.py::test_klint_32m_parameter_scale PASSED         [ 90%]
# tests/test_transformer.py::test_klint_generation_order PASSED            [100%]
#
# ============================== 11 passed in 2.89s ==============================

# %% [markdown]
# ## 3. Stage 1: Factor Tokenizer Pre-training (RVQ Codebooks)
# Pre-trains the 3 discrete factor codebooks (512 Price, 256 Range, 256 Activity) on market bars. (If you already have `checkpoints/tokenizer_best.pt`, this completes immediately).

# %%
# Train or verify tokenizer codebooks
if not os.path.exists('checkpoints/tokenizer_best.pt'):
    print('Training tokenizer codebooks from scratch...')
    # !python scripts/train_tokenizer.py \
        --data_path data/SOL.npy \
        --epochs 10 \
        --batch_size 128 \
        --learning_rate 0.001 \
        --save_dir checkpoints
else:
    print('Trained tokenizer found: checkpoints/tokenizer_best.pt (Ready)')
# Out:
# Trained tokenizer found: checkpoints/tokenizer_best.pt (Ready)

# %% [markdown]
# ## 4. Stage 2: Discrete Token Caching (50x Training Acceleration)
# Pre-encodes all 1.59M bars into integer token IDs `data/sol_tokens.pt`.

# %%
if not os.path.exists('data/sol_tokens.pt'):
    # !python scripts/cache_tokens.py \
        --data_path data/SOL.npy \
        --tokenizer_path checkpoints/tokenizer_best.pt \
        --output_path data/sol_tokens.pt \
        --batch_size 16384
else:
    print('Cached tokens found: data/sol_tokens.pt (Ready)')
# Out:
# Cached tokens found: data/sol_tokens.pt (Ready)

# %% [markdown]
# ## 5. Stage 3: High-Speed Klint-32M Foundation Model Training
# **Resume & Turbocharged Training:** Loads existing weights (`checkpoints/klint_32m_step_1500.pt` or `checkpoints/klint_32m_best.pt`), puts tokens directly into GPU VRAM, and continues training forward at **30,000+ tokens/sec** with zero memory bus bottlenecks.

# %%
# Prevent CUDA memory fragmentation
# %env PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True

# Check for existing checkpoint to resume from
resume_ckpt = None
for candidate in ['checkpoints/klint_32m_step_1500.pt', 'checkpoints/klint_32m_best.pt']:
    if os.path.exists(candidate):
        resume_ckpt = candidate
        break

resume_flag = f"--resume_from {resume_ckpt}" if resume_ckpt else ""
print(f"Training mode: {'RESUMING from ' + resume_ckpt if resume_ckpt else 'TRAINING FROM SCRATCH'}")

# Fast In-VRAM training: 256 bars context (768 tokens) = ~4.2h intraday dynamics
# !python scripts/train_klint32m.py \
    --tokens_path data/sol_tokens.pt \
    --save_dir checkpoints \
    {resume_flag} \
    --max_steps 3000 \
    --batch_size 8 \
    --grad_accum_steps 4 \
    --learning_rate 0.0003 \
    --warmup_steps 200 \
    --eval_interval 200 \
    --save_interval 500 \
    --context_bars 256 \
    --no_gradient_checkpointing
# Out:
# env: PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True
# Training mode: RESUMING from checkpoints/klint_32m_best.pt
# ============================================================
#  Klint: Stage 3 - High-Speed Training Klint-32M on CUDA
# ============================================================
# Loaded 1,591,983 bars (4,775,949 tokens) from data/sol_tokens.pt
# Sequence length: 256 bars = 768 tokens
# Effective batch size: 32 (Micro-batch=8, Accum=4)
# Gradient Checkpointing: False
# Using In-VRAM Direct Tensor Slicing (Zero CPU-GPU memory bus overhead)
# Trainable Parameters: 28,642,560
# --> Resuming weights from: checkpoints/klint_32m_best.pt
# --> Resumed starting step: 1,800
# --> Previous best validation loss: 2.7662
# Step  1820/ 3000 | Loss: 3.8337 | LR: 1.32e-04 | Speed: 716,390 tok/s
# Step  1840/ 3000 | Loss: 3.2771 | LR: 1.29e-04 | Speed: 361,986 tok/s
# Step  1860/ 3000 | Loss: 3.1166 | LR: 1.26e-04 | Speed: 243,809 tok/s
# Step  1880/ 3000 | Loss: 3.0901 | LR: 1.23e-04 | Speed: 184,924 tok/s
# Step  1900/ 3000 | Loss: 2.9890 | LR: 1.21e-04 | Speed: 149,524 tok/s
# Step  1920/ 3000 | Loss: 3.1331 | LR: 1.18e-04 | Speed: 125,926 tok/s
# Step  1940/ 3000 | Loss: 2.9993 | LR: 1.15e-04 | Speed: 109,077 tok/s
# Step  1960/ 3000 | Loss: 2.9054 | LR: 1.12e-04 | Speed: 96,424 tok/s
# Step  1980/ 3000 | Loss: 2.9081 | LR: 1.09e-04 | Speed: 86,585 tok/s
# Step  2000/ 3000 | Loss: 2.9217 | LR: 1.07e-04 | Speed: 78,718 tok/s
#
# [EVAL] Step 2000 | Validation Cross-Entropy Loss: 2.4000
#
#   --> Saved new best checkpoint to checkpoints/klint_32m_best.pt
# Saved periodic checkpoint: checkpoints/klint_32m_step_2000.pt
# Step  2020/ 3000 | Loss: 2.9628 | LR: 1.04e-04 | Speed: 71,635 tok/s
# Step  2040/ 3000 | Loss: 2.9295 | LR: 1.01e-04 | Speed: 66,355 tok/s
# Step  2060/ 3000 | Loss: 2.9427 | LR: 9.85e-05 | Speed: 61,882 tok/s
# Step  2080/ 3000 | Loss: 2.8489 | LR: 9.59e-05 | Speed: 58,043 tok/s
# Step  2100/ 3000 | Loss: 2.9668 | LR: 9.33e-05 | Speed: 54,715 tok/s
# Step  2120/ 3000 | Loss: 2.8793 | LR: 9.08e-05 | Speed: 51,804 tok/s
# Step  2140/ 3000 | Loss: 2.8344 | LR: 8.82e-05 | Speed: 49,236 tok/s
# Step  2160/ 3000 | Loss: 2.8176 | LR: 8.58e-05 | Speed: 46,946 tok/s
# Step  2180/ 3000 | Loss: 2.9570 | LR: 8.33e-05 | Speed: 44,901 tok/s
# Step  2200/ 3000 | Loss: 2.8804 | LR: 8.09e-05 | Speed: 43,058 tok/s
#
# [EVAL] Step 2200 | Validation Cross-Entropy Loss: 2.3747
#
#   --> Saved new best checkpoint to checkpoints/klint_32m_best.pt
# Step  2220/ 3000 | Loss: 2.9899 | LR: 7.86e-05 | Speed: 41,199 tok/s
# Step  2240/ 3000 | Loss: 2.9203 | LR: 7.63e-05 | Speed: 39,696 tok/s
# Step  2260/ 3000 | Loss: 2.8803 | LR: 7.40e-05 | Speed: 38,323 tok/s
# Step  2280/ 3000 | Loss: 2.8933 | LR: 7.18e-05 | Speed: 37,063 tok/s
# Step  2300/ 3000 | Loss: 2.9472 | LR: 6.96e-05 | Speed: 35,904 tok/s
# Step  2320/ 3000 | Loss: 2.8381 | LR: 6.75e-05 | Speed: 34,831 tok/s
# Step  2340/ 3000 | Loss: 2.8078 | LR: 6.55e-05 | Speed: 33,838 tok/s
# Step  2360/ 3000 | Loss: 2.8272 | LR: 6.34e-05 | Speed: 32,916 tok/s
# Step  2380/ 3000 | Loss: 2.8412 | LR: 6.15e-05 | Speed: 32,058 tok/s
# Step  2400/ 3000 | Loss: 2.7754 | LR: 5.95e-05 | Speed: 31,257 tok/s
#
# [EVAL] Step 2400 | Validation Cross-Entropy Loss: 2.3607
#
#   --> Saved new best checkpoint to checkpoints/klint_32m_best.pt
# Step  2420/ 3000 | Loss: 2.8902 | LR: 5.77e-05 | Speed: 30,413 tok/s
# Step  2440/ 3000 | Loss: 2.8569 | LR: 5.59e-05 | Speed: 29,715 tok/s
# Step  2460/ 3000 | Loss: 2.8827 | LR: 5.41e-05 | Speed: 29,059 tok/s
# Step  2480/ 3000 | Loss: 2.8331 | LR: 5.24e-05 | Speed: 28,442 tok/s
# Step  2500/ 3000 | Loss: 2.9844 | LR: 5.08e-05 | Speed: 27,860 tok/s
# Saved periodic checkpoint: checkpoints/klint_32m_step_2500.pt
# Step  2520/ 3000 | Loss: 2.8503 | LR: 4.92e-05 | Speed: 27,309 tok/s
# Step  2540/ 3000 | Loss: 2.7967 | LR: 4.77e-05 | Speed: 26,788 tok/s
# Step  2560/ 3000 | Loss: 2.8485 | LR: 4.62e-05 | Speed: 26,295 tok/s
# Step  2580/ 3000 | Loss: 2.8206 | LR: 4.48e-05 | Speed: 25,826 tok/s
# Step  2600/ 3000 | Loss: 2.8147 | LR: 4.34e-05 | Speed: 25,381 tok/s
#
# [EVAL] Step 2600 | Validation Cross-Entropy Loss: 2.3486
#
#   --> Saved new best checkpoint to checkpoints/klint_32m_best.pt
# Step  2620/ 3000 | Loss: 2.8873 | LR: 4.21e-05 | Speed: 24,900 tok/s
# Step  2640/ 3000 | Loss: 2.8017 | LR: 4.09e-05 | Speed: 24,499 tok/s
# Step  2660/ 3000 | Loss: 2.8403 | LR: 3.98e-05 | Speed: 24,116 tok/s
# Step  2680/ 3000 | Loss: 2.8866 | LR: 3.87e-05 | Speed: 23,751 tok/s
# Step  2700/ 3000 | Loss: 2.9326 | LR: 3.76e-05 | Speed: 23,401 tok/s
# Step  2720/ 3000 | Loss: 2.8410 | LR: 3.67e-05 | Speed: 23,067 tok/s
# Step  2740/ 3000 | Loss: 2.8553 | LR: 3.57e-05 | Speed: 22,747 tok/s
# Step  2760/ 3000 | Loss: 2.8098 | LR: 3.49e-05 | Speed: 22,439 tok/s
# Step  2780/ 3000 | Loss: 2.7767 | LR: 3.41e-05 | Speed: 22,144 tok/s
# Step  2800/ 3000 | Loss: 2.8534 | LR: 3.34e-05 | Speed: 21,861 tok/s
#
# [EVAL] Step 2800 | Validation Cross-Entropy Loss: 2.3447
#
#   --> Saved new best checkpoint to checkpoints/klint_32m_best.pt
# Step  2820/ 3000 | Loss: 2.8887 | LR: 3.28e-05 | Speed: 21,548 tok/s
# Step  2840/ 3000 | Loss: 2.7613 | LR: 3.22e-05 | Speed: 21,286 tok/s
# Step  2860/ 3000 | Loss: 2.8521 | LR: 3.17e-05 | Speed: 21,035 tok/s
# Step  2880/ 3000 | Loss: 2.8863 | LR: 3.12e-05 | Speed: 20,793 tok/s
# Step  2900/ 3000 | Loss: 2.8102 | LR: 3.09e-05 | Speed: 20,560 tok/s
# Step  2920/ 3000 | Loss: 2.9120 | LR: 3.06e-05 | Speed: 20,335 tok/s
# Step  2940/ 3000 | Loss: 2.9255 | LR: 3.03e-05 | Speed: 20,118 tok/s
# Step  2960/ 3000 | Loss: 2.8060 | LR: 3.01e-05 | Speed: 19,908 tok/s
# Step  2980/ 3000 | Loss: 2.8639 | LR: 3.00e-05 | Speed: 19,705 tok/s
# Step  3000/ 3000 | Loss: 2.8193 | LR: 3.00e-05 | Speed: 19,509 tok/s
#
# [EVAL] Step 3000 | Validation Cross-Entropy Loss: 2.3319
#
#   --> Saved new best checkpoint to checkpoints/klint_32m_best.pt
# Saved periodic checkpoint: checkpoints/klint_32m_step_3000.pt
#
# Training Finished Successfully!

# %% [markdown]
# ## 6. Stage 4: Package Full Model Bundle for Easy Download
# Combines the trained Tokenizer + Klint-32M weights + architecture configuration into `./checkpoints/klint_32m_release.pt`.

# %%
import os, sys
sys.path.insert(0, '/content/Klint-32M/src')
sys.path.insert(0, os.path.abspath('src'))

import torch
from klint.models.klint_32m import Klint32M, KlintConfig
from klint.tokenizer.factor_tokenizer import FactorTokenizer

bundle_path = "checkpoints/klint_32m_release.pt"
tok_ckpt = torch.load("checkpoints/tokenizer_best.pt", map_location="cpu", weights_only=False)
model_ckpt = torch.load("checkpoints/klint_32m_best.pt", map_location="cpu", weights_only=False)

torch.save({
    "architecture": "Klint-32M",
    "author": "Akhilesh Varma",
    "config": model_ckpt["config"],
    "tokenizer_state_dict": tok_ckpt,
    "model_state_dict": model_ckpt["model_state_dict"],
    "val_loss": model_ckpt.get("val_loss", None),
    "step": model_ckpt.get("step", None),
}, bundle_path)

bundle_size_mb = os.path.getsize(bundle_path) / (1024 * 1024)
print(f"Unified release bundle created: {bundle_path} ({bundle_size_mb:.2f} MB)")

# Optional: Trigger browser download to your local machine
# from google.colab import files
# files.download(bundle_path)
# Out:
# Unified release bundle created: checkpoints/klint_32m_release.pt (109.91 MB)

# %% [markdown]
# ## 7. Stage 5: Generative Trajectory Sampling & Candlestick Visualization
# Generates 100 synthetic market bars using causal factor routing ($P \to R \to A$) and verifies 100% geometric invariant satisfaction.

# %%
import os, sys
sys.path.insert(0, '/content/Klint-32M/src')
sys.path.insert(0, os.path.abspath('src'))

import numpy as np
import matplotlib.pyplot as plt
import torch

from klint.tokenizer.factor_tokenizer import FactorTokenizer
from klint.tokenizer.geometric_decoder import GeometricDecoder
from klint.models.klint_32m import Klint32M, KlintConfig
from klint.data.validator import validate_ohlcv

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
bundle = torch.load("checkpoints/klint_32m_release.pt", map_location=device, weights_only=False)

tokenizer = FactorTokenizer().to(device)
tokenizer.load_state_dict(bundle["tokenizer_state_dict"])
tokenizer.eval()

model = Klint32M(bundle["config"]).to(device)
model.load_state_dict(bundle["model_state_dict"])
model.eval()
decoder = GeometricDecoder()

# Prompt with last 50 bars
tokens_data = torch.load("data/sol_tokens.pt", map_location="cpu", weights_only=False)
prompt_tokens = tokens_data["token_matrix"][-50:].view(1, -1).to(device)
num_future_bars = 100

gen_tokens = model.generate_tokens(prompt_tokens, num_bars=num_future_bars, temperature=0.8, top_k=40)
new_tokens = gen_tokens[:, 150:]

p_tok, r_tok, a_tok = tokenizer.deinterleave(new_tokens)
rec_p, rec_r, rec_a = tokenizer.decode_tokens(p_tok, r_tok, a_tok)
synth_bars = decoder(rec_p, rec_r, rec_a, anchor_price=float(tokens_data.get("anchor_price", 100.0))).squeeze(0).detach().cpu().numpy()

is_valid, report = validate_ohlcv(synth_bars)
print(f"Generated Candles Invariant Validity: {is_valid} | Violations: {report['total_violations']}")

# Candlestick Chart
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(14, 8), gridspec_kw={'height_ratios': [3, 1]}, sharex=True)
for i in range(len(synth_bars)):
    o, h, l, c, v = synth_bars[i]
    color = '#26a69a' if c >= o else '#ef5350'
    ax1.plot([i, i], [l, h], color=color, linewidth=1.2)
    ax1.add_patch(plt.Rectangle((i - 0.35, min(o, c)), 0.7, max(abs(c - o), 0.001), color=color, alpha=0.9))
    ax2.bar(i, v, color=color, width=0.7, alpha=0.8)

ax1.set_title("Klint-32M: Synthetic Generated Market Trajectory (100 Bars)", fontsize=14, fontweight='bold')
ax1.set_ylabel("Price ($)", fontsize=12)
ax1.grid(True, alpha=0.2)
ax2.set_ylabel("Volume", fontsize=12)
ax2.set_xlabel("Bar Step (t)", fontsize=12)
ax2.grid(True, alpha=0.2)
plt.tight_layout()
plt.savefig("checkpoints/synthetic_market_trajectory.png", dpi=150)
plt.show()
# Out:
# Generated Candles Invariant Validity: True | Violations: 0

# %% [markdown]
# ## 8. Stage 6: Rigorous Multi-Asset Testing Suite (300+ Assets via yfinance)
# Tests the trained Klint-32M foundation model across **300+ liquid assets across 6 asset classes** (Equities, ETFs, Crypto, Commodities, FX, Bonds):
# * Calculates **Directional Hit Rate (%)**, **Annualized Sharpe**, **Sortino**, **Max Drawdown (%)**, and **Cumulative PnL**.
# * Exports 4 comprehensive CSV scorecards to `benchmarks/reports/`.
# * Generates and plots publication-quality performance graphs to `benchmarks/plots/`.

# %%
# Execute the full multi-asset benchmark suite across 300+ assets
# !python scripts/run_multi_asset_benchmark.py \
    --checkpoint checkpoints/klint_32m_best.pt \
    --tokenizer_checkpoint checkpoints/tokenizer_best.pt \
    --max_assets 320 \
    --period 1y \
    --interval 1d \
    --context_bars 64 \
    --output_dir benchmarks
# Out:
# ======================================================================
#  Klint-32M: Quantitative Multi-Asset Benchmark (CUDA)
# ======================================================================
# Loading Klint-32M foundation model from: checkpoints/klint_32m_best.pt
# Loading Factor Tokenizer from: checkpoints/tokenizer_best.pt
# Selected 307 assets across 6 asset classes.
# Fetching market data for 307 assets (period=1y, interval=1d)...
#   --> Processed 25/307 assets (25 valid datasets fetched)
#   --> Processed 50/307 assets (50 valid datasets fetched)
# HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"Quote not found for symbol: BK"}}}
# $BK: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
#   --> Processed 75/307 assets (74 valid datasets fetched)
#   --> Processed 100/307 assets (99 valid datasets fetched)
#   --> Processed 125/307 assets (124 valid datasets fetched)
#   --> Processed 150/307 assets (149 valid datasets fetched)
#   --> Processed 175/307 assets (174 valid datasets fetched)
# $SUI-USD: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $APT-USD: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $FTM-USD: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
#   --> Processed 200/307 assets (195 valid datasets fetched)
# $MATIC-USD: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $STX-USD: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $IMX-USD: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
# $UNI-USD: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
#   --> Processed 225/307 assets (216 valid datasets fetched)
# $COW: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")
#   --> Processed 250/307 assets (240 valid datasets fetched)
#   --> Processed 275/307 assets (264 valid datasets fetched)
#   --> Processed 300/307 assets (289 valid datasets fetched)
#   --> Processed 307/307 assets (296 valid datasets fetched)
# Successfully loaded data for 296 assets.
#
# Evaluating Klint-32M across 296 assets...
#   --> Benchmarked 25/296 assets | Valid results: 25
#   --> Benchmarked 50/296 assets | Valid results: 50
#   --> Benchmarked 75/296 assets | Valid results: 75
#   --> Benchmarked 100/296 assets | Valid results: 100
#   --> Benchmarked 125/296 assets | Valid results: 125
#   --> Benchmarked 150/296 assets | Valid results: 150
#   --> Benchmarked 175/296 assets | Valid results: 175
#   --> Benchmarked 200/296 assets | Valid results: 200
#   --> Benchmarked 225/296 assets | Valid results: 225
#   --> Benchmarked 250/296 assets | Valid results: 250
#   --> Benchmarked 275/296 assets | Valid results: 275
# /usr/local/lib/python3.13/dist-packages/numpy/_core/_methods.py:227: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /usr/local/lib/python3.13/dist-packages/numpy/_core/_methods.py:184: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /usr/local/lib/python3.13/dist-packages/numpy/_core/_methods.py:219: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
#   --> Benchmarked 296/296 assets | Valid results: 296
#
# Exported Benchmark CSV Reports:
#   1. benchmarks/reports/asset_benchmark_summary.csv
#   2. benchmarks/reports/asset_ranking.csv
#   3. benchmarks/reports/asset_class_aggregate.csv
#   4. benchmarks/reports/drawdown_equity_log.csv
#
# Generating Publication-Grade Benchmark Plots...
#   1. Drawdown Curves: benchmarks/plots/drawdown_equity_curves.png
#   2. Accuracy Distribution: benchmarks/plots/directional_accuracy_dist.png
#   3. Sharpe Rankings: benchmarks/plots/asset_sharpe_ranking.png
#   4. Asset Class Comparison: benchmarks/plots/asset_class_comparison.png
#
# ======================================================================
#  BENCHMARK PERFORMANCE HIGHLIGHTS
# ======================================================================
#   Total Assets Evaluated:         296
#   Mean Directional Accuracy:      47.73%
#   Median Directional Accuracy:    48.00%
#   Assets with Accuracy > 50%:     33.8%
#   Mean Annualized Sharpe:         -3.740
#   Median Annualized Sharpe:       -0.663
#   Mean Maximum Drawdown:          -26.57%
#   Candle Invariant Validity:      100.00% (Guaranteed)
# ======================================================================
# All CSV reports and visualization charts saved successfully.

# %% [markdown]
# ## 9. Stage 7: Display Benchmark Visualizations & Asset Ranking
# Displays the generated quantitative charts inline and previews the top-ranked assets.

# %%
from IPython.display import Image, display
import pandas as pd

# 1. Display Visualizations
plots = [
    ("Equity & Underwater Drawdown Curves", "benchmarks/plots/drawdown_equity_curves.png"),
    ("Directional Accuracy Distribution vs 50% Random Walk", "benchmarks/plots/directional_accuracy_dist.png"),
    ("Top Asset Sharpe Ratio Rankings", "benchmarks/plots/asset_sharpe_ranking.png"),
    ("Cross-Asset Class Performance Comparison", "benchmarks/plots/asset_class_comparison.png"),
]

for title, path in plots:
    if os.path.exists(path):
        print(f"=== {title} ===")
        display(Image(filename=path))

# 2. Display Top 15 Ranked Assets Table
ranking_csv = "benchmarks/reports/asset_ranking.csv"
if os.path.exists(ranking_csv):
    df_rank = pd.read_csv(ranking_csv)
    cols = ["Rank", "Ticker", "Name", "Asset_Class", "Directional_Accuracy_Pct", "Annualized_Sharpe", "Max_Drawdown_Pct", "Cumulative_Return_Pct", "Win_Rate_Pct"]
    print("\n=== TOP 15 RANKED ASSETS BY ANNUALIZED SHARPE RATIO ===")
    display(df_rank[cols].head(15))

# 3. Display Asset Class Summary Table
class_csv = "benchmarks/reports/asset_class_aggregate.csv"
if os.path.exists(class_csv):
    df_class = pd.read_csv(class_csv)
    print("\n=== CROSS-ASSET CLASS AGGREGATE SUMMARY ===")
    display(df_class)
# Out:
# === Equity & Underwater Drawdown Curves ===
# === Directional Accuracy Distribution vs 50% Random Walk ===
# === Top Asset Sharpe Ratio Rankings ===
# === Cross-Asset Class Performance Comparison ===
# === TOP 15 RANKED ASSETS BY ANNUALIZED SHARPE RATIO ===
#     Rank    Ticker                              Name  Asset_Class  \
# 0      1      PANW                Palo Alto Networks     Equities
# 1      2       UGA       United States Gasoline Fund  Commodities
# 2      3      FTNT                     Fortinet Inc.     Equities
# 3      4      ARKG        ARK Genomic Revolution ETF         ETFs
# 4      5      CRWD              CrowdStrike Holdings     Equities
# 5      6       VLO                     Valero Energy     Equities
# 6      7      DDOG                      Datadog Inc.     Equities
# 7      8      ARKW  ARK Next Generation Internet ETF         ETFs
# 8      9       MPC                Marathon Petroleum     Equities
# 9     10        ZS                      Zscaler Inc.     Equities
# 10    11      WDAY                      Workday Inc.     Equities
# 11    12       AMD            Advanced Micro Devices     Equities
# 12    13       TMO          Thermo Fisher Scientific     Equities
# 13    14  NEAR-USD                 NEAR Protocol USD       Crypto
# 14    15      TEAM                   Atlassian Corp.     Equities
#
#     Directional_Accuracy_Pct  Annualized_Sharpe  Max_Drawdown_Pct  \
# 0                      56.00              3.763            -16.00
# 1                      61.33              2.803            -11.23
# 2                      56.00              2.550            -24.71
# 3                      54.67              2.431            -12.60
# 4                      58.00              2.403            -22.11
# 5                      54.67              2.380             -9.76
# 6                      54.00              2.345            -23.60
# 7                      55.33              2.308            -14.60
# 8                      60.67              2.273            -13.37
# 9                      56.67              2.246            -24.30
# 10                     53.33              2.148            -23.35
# 11                     58.00              2.054            -24.80
# 12                     56.00              2.000            -14.11
# 13                     48.00              1.998            -50.83
# 14                     55.33              1.963            -37.46
#
#     Cumulative_Return_Pct  Win_Rate_Pct
# 0                  167.81         55.33
# 1                   57.47         60.27
# 2                   76.79         55.41
# 3                   63.74         54.00
# 4                   97.78         56.67
# 5                   54.45         53.38
# 6                   90.00         53.02
# 7                   39.46         54.67
# 8                   48.49         59.33
# 9                   84.54         56.85
# 10                  78.58         53.69
# 11                  67.67         55.33
# 12                  32.16         54.67
# 13                 130.10         48.00
# 14                  77.71         54.93
# === CROSS-ASSET CLASS AGGREGATE SUMMARY ===
#     Asset_Class  Asset_Count  Mean_Directional_Accuracy_Pct  \
# 0   Commodities           28                          53.57
# 1        Crypto           43                          43.40
# 2      Equities          128                          49.22
# 3          ETFs           50                          49.12
# 4  Fixed_Income           20                          40.97
# 5            FX           27                          43.95
#
#    Median_Directional_Accuracy_Pct  Mean_Annualized_Sharpe  \
# 0                            54.67                   0.236
# 1                            47.33                  -0.185
# 2                            48.67                  -0.590
# 3                            49.33                  -0.659
# 4                            41.33                  -5.409
# 5                            45.33                 -32.932
#
#    Median_Annualized_Sharpe  Mean_Max_Drawdown_Pct  \
# 0                     0.512                 -13.17
# 1                    -0.020                 -67.36
# 2                    -0.784                 -26.14
# 3                    -0.616                 -17.08
# 4                    -5.670                  -9.10
# 5                   -27.831                  -8.03
#
#    Mean_Cumulative_Return_Pct  Mean_Win_Rate_Pct  Mean_Profit_Factor  \
# 0                3.060000e+00              51.68               1.066
# 1               -9.135249e+10              42.63               0.995
# 2               -2.690000e+00              48.09               0.940
# 3               -3.730000e+00              46.97               0.921
# 4               -8.660000e+00              26.47               0.309
# 5               -7.710000e+00              11.61               0.169
#
#   Candle_Invariant_Pass_Rate
# 0                     100.0%
# 1                     100.0%
# 2                     100.0%
# 3                     100.0%
# 4                     100.0%
# 5                     100.0%
